# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
#BASICS MATPLOTLIB

# %%
x = np.linspace(0,5,11)
x
y = x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title('hello')
plt.xlabel('chahcha')
plt.ylabel('chahchi')
# Out:
# Text(0, 0.5, 'chahchi')

# %%
#sunplots aik sath ,ultiple plots banana

# %%
plt.subplot(2,2,1)
plt.plot(x,y)

plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,3)

plt.subplot(2,2,4)
plt.plot(x,y)

# %%
#object orinted way

# %%
fig  =plt.figure(figsize=(20,8),dpi=100)
axis1= fig.add_axes([0.1,0.1,1,1])
axis1.plot(x,y)
axis2 =fig.add_axes([0.2,0.8,.3,.3])
axis2.plot(x,y)

# %%
#types of plot

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 5., 15., 12., 11., 10., 12., 10.,  9.,  5., 11.]),
#  array([ 21. , 117.1, 213.2, 309.3, 405.4, 501.5, 597.6, 693.7, 789.8,
#         885.9, 982. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d75276e90>,
#   <matplotlib.lines.Line2D at 0x20d75276fd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x20d75277110>,
#   <matplotlib.lines.Line2D at 0x20d75277250>],
#  'boxes': [<matplotlib.lines.Line2D at 0x20d75276d50>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d75277390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d752774d0>],
#  'means': []}

# %%
#saving plots in device

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)

# %%
plt.savefig('basicplt.png')

# %%
#working with images

# %%
import matplotlib.image as npimg
